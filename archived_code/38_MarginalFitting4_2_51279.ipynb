# %% [markdown]
# # Do the actual fitting marginally.  Separate the gene list into 4 subsets of 6 each.  Track also the time and memory usage in the meanwhile.

# %%
# %run -i ~/project/preambles
# %run -i ~/project/helper_functions
# %run -i ~/project/fitting_functions
# %load_ext memory_profiler
# # Global parameters:
number_of_cycles = 50 # how many passes through the training data we go through
number_of_groups = 10 # divide the data set into smaller ones, to make fitting easier.
steps_per_batch = 5
dims = 2  # 2D spatial
head = 0 # how many locations to consider in the real data set.
# Out:
# cpu

# %%
puck_list = ['Puck_230517_39'] # the largest puck
gene_list = [ "Inha", "Inhba", "Inhbb", "Fst", "Esr1", "Esr2", "Pgr", "Ar", "Cyp19a1", 
    "Cyp17a1", "Cyp11a1", "Lhcgr", "Parm1", "Akr1c18", "Fshr", "Star", "Ptgfr", 
    "Sfrp4", "Acvr1", "Acvr2a", "Acvr2b", "Ghr", "Lhb", "Cga"]
# gene_list = gene_list[:6]  # First 6 elements
# gene_list = gene_list[6:12]  # Next 6 elements
# gene_list = gene_list[12:18]  # Next 6 elements
gene_list = gene_list[18:]  # Remaining elements
adata, X,Y, gene_list=load_data(gene_list=gene_list, head=head, puck_list = puck_list)
# Out:
# ['Lhb', 'Cga'] dropped from gene_list due to not being observed.

# %% [markdown]
# # Fitting Codes

# %%
# %%memit
# start_time = time.time()
# optimized_marginal_params = optimize_marginal_parameters(X, Y, number_of_groups,  number_of_cycles, steps_per_batch)
# end_time = time.time()
# print(f"Time taken: {(end_time - start_time)/3600:.6f} hours")
# Out:
# Error encountered during epoch 0: linalg.cholesky: The factorization could not be completed because the input is not positive-definite (the leading minor of order 1150 is not positive-definite).
# Parameters that caused the error -> nu_i: 1.0254539825493363, alpha_i: 0.008573524016146073, sigma_i: 1.2798698020565846
# 0.008573524016146073 1.0254539825493363 1.2798698020565846
# Error encountered during epoch 0: linalg.cholesky: The factorization could not be completed because the input is not positive-definite (the leading minor of order 1150 is not positive-definite).
# Parameters that caused the error -> nu_i: 1.0116561820417058, alpha_i: 0.009113324692536772, sigma_i: 1.2716371601086718
# 0.009113324692536772 1.0116561820417058 1.2716371601086718
# Error encountered during epoch 0: linalg.cholesky: The factorization could not be completed because the input is not positive-definite (the leading minor of order 1150 is not positive-definite).
# Parameters that caused the error -> nu_i: 1.0266897654614493, alpha_i: 0.008630110278986323, sigma_i: 1.2647187728914042
# 0.008630110278986323 1.0266897654614493 1.2647187728914042
# Error encountered during epoch 0: linalg.cholesky: The factorization could not be completed because the input is not positive-definite (the leading minor of order 1150 is not positive-definite).
# Parameters that caused the error -> nu_i: 1.0213750481837238, alpha_i: 0.008744264234066108, sigma_i: 1.270179819082445
# 0.008744264234066108 1.0213750481837238 1.270179819082445
# Time taken: 5.992929 hours
# peak memory: 26560.84 MiB, increment: 24459.90 MiB

# %%
# Run this block only on slurm
df_to_plot = pd.DataFrame(optimized_marginal_params)
notebook_name = "38_4_2"
histograms_are_plotted = False
# %run -i epilogue
# Out:
# DataFrame saved to /home/zc362/project/python_processed_data/38_4_2_job_51279_time_20241022_203437.csv

# %% [markdown]
# # The outputs are (alpha_i.item(), nu_i.item(), sigma_i.item()) of the genes.

# %%
optimized_marginal_params
# Out:
# [(0.008573524016146073, 1.0254539825493363, 1.2798698020565846),
#  (0.009113324692536772, 1.0116561820417058, 1.2716371601086718),
#  (0.008630110278986323, 1.0266897654614493, 1.2647187728914042),
#  (0.008744264234066108, 1.0213750481837238, 1.270179819082445)]

# %%
gene_list
# Out:
# ['Acvr1', 'Acvr2a', 'Acvr2b', 'Ghr']
