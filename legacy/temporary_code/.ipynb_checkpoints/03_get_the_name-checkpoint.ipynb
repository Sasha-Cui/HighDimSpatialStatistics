# %%
import time 
time.ctime(time.time())
# Out:
# 'Tue Oct  1 13:12:51 2024'

# %%
import json
import os
import requests
from notebook import notebookapp

def get_notebook_name():
    # Get the connection file and extract the kernel ID
    connection_file = os.path.basename(get_ipython().config['IPKernelApp']['connection_file'])
    kernel_id = connection_file.split('-', 1)[1].split('.')[0]

    # Find the notebook server and request the API for sessions
    for srv in notebookapp.list_running_servers():
        try:
            response = requests.get(f"{srv['url']}api/sessions", params={'token': srv.get('token', '')})
            for sess in json.loads(response.text):
                if sess['kernel']['id'] == kernel_id:
                    return sess['notebook']['path'].split('/')[-1]
        except Exception as e:
            print(f"An error occurred: {e}")
    
    return None

notebook_name = get_notebook_name()
print(f"Notebook name: {notebook_name}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 4
#       2 import os
#       3 import requests
# ----> 4 from notebook import notebookapp
#       6 def get_notebook_name():
#       7     # Get the connection file and extract the kernel ID
#       8     connection_file = os.path.basename(get_ipython().config['IPKernelApp']['connection_file'])
#
# ImportError: cannot import name 'notebookapp' from 'notebook' (/home/zc362/.conda/envs/myenv/lib/python3.12/site-packages/notebook/__init__.py)

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /home/zc362/.conda/envs/myenv/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zc362/.conda/envs/myenv/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/zc362/.conda/envs/myenv/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zc362/.conda/envs/myenv/lib/python3.12/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zc362/.conda/envs/myenv/lib/python3.12/site-packages (from requests) (2024.8.30)
