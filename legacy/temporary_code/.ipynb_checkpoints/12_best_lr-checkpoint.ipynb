# %%
# %run -i ~/project/preambles
# %run -i ~/project/temporary_code/helper_functions
# %run -i ~/project/temporary_code/fitting_functions
# Out:
# cuda

# %%
# %load_ext memory_profiler
import itertools

# %%
# # Global parameters:
number_of_cycles = 1000 # how many passes through the training data we go through
number_of_groups = 1 # divide the data set into smaller ones, to make fitting easier.
steps_per_batch = 1
dims = 2  # 2D spatial
head = 5000 # how many locations to consider in the real data set.

# %%
puck_list = ['Puck_230517_39'] # the largest puck
gene_list = [ "Inha"]
adata, X,Y, gene_list=load_data(gene_list=gene_list, head=head, puck_list = puck_list)

# %%
# %%memit
# start_time = time.time()
# optimized_marginal_params = optimize_marginal_parameters(X, Y, number_of_groups,  number_of_cycles, steps_per_batch, print_early_stopping_epochs = True)
# end_time = time.time()
# print(f"Time taken: {(end_time - start_time)/3600:.6f} hours")

# %% [markdown]
# ## Let us look back at the synthetic data set

# %%
# # Global parameters:
number_of_cycles = 1000 # how many passes through the training data we go through
number_of_groups = 1 # divide the data set into smaller ones, to make fitting easier.
locations_per_group = 200 # how many locations to observe per group
number_of_locations = number_of_groups * locations_per_group # total locations
number_of_simulations = 300 # for synthetic data, how many optimisation to average over
steps_per_batch = 1
dims = 2  # 2D spatial
p =  3 # how many features

# %%
X,Y,true_K, alpha_matrix_true, nu_matrix_true, sigma_matrix_true = Genton_parametrisation(number_of_locations, dims)
ground_truth_df = store_as_df(alpha_matrix_true, nu_matrix_true, sigma_matrix_true)
estimated_params_df = pd.DataFrame()
distance_K_df = pd.DataFrame()
for _ in range(1,301):
    print(f"data set {_}")
    try:
        df = pd.read_csv(f'~/project/synthetic_data/realisation_{_}.csv')
        X = torch.tensor(df[['0','1']].values[:200], dtype=torch.float64).detach()
        expression = df['Expression'].values.reshape(200, 3)
        Y = torch.tensor(expression, dtype=torch.float64).detach()
        torch.autograd.set_detect_anomaly(True)
        optimized_marginal_params = optimize_marginal_parameters(X, Y, number_of_groups,  number_of_cycles, steps_per_batch)
        print(optimized_marginal_params)
    except Exception as e:
        print(e)
        continue
# Out:
# data set 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 13
#      11     Y = torch.tensor(expression, dtype=torch.float64).detach()
#      12     torch.autograd.set_detect_anomaly(True)
# ---> 13     optimized_marginal_params = optimize_marginal_parameters(X, Y, number_of_groups,  number_of_cycles, steps_per_batch)
#      14     print(optimized_marginal_params)
#      15 except Exception as e:
#
# File /gpfs/radev/project/ma_zongming/zc362/temporary_code/fitting_functions.py:98, in optimize_marginal_parameters(X, Y, number_of_groups, number_of_cycles, steps_per_batch, print_early_stopping_epochs)
#      93 for X_batch, Y_batch in zip(X_groups, Y_groups):
#      94     # X_batch = X_batch.to(device)
#      95     # Y_batch = Y_batch.to(device)
#      96     for _ in range(steps_per_batch):
#      97         # Compute the covariance matrix K
# ---> 98         K = approx_matern_kernel_marginal(X_batch, alpha_i, nu_i, sigma_i)
#      99         ## 10 Oct 2024 replaced the following two lines with the line above
#     100         ## K = matern_kernel(torch.cdist(X_batch, X_batch), alpha_i, nu_i, sigma_i)
#     101         ## K += torch.eye(K.size(0), device=device) * 1e-9
#     102
#     103         # Compute the NLL for the batch
#     104         nll = negative_log_likelihood(Y_batch[:, i], K)
#
# File /gpfs/radev/project/ma_zongming/zc362/temporary_code/helper_functions.py:408, in approx_matern_kernel_marginal(X, alpha_i, nu_i, sigma_i, epsilon, number_of_distances)
#     406 # Compute the kernel for each distance and store it in the tensor
#     407 for i, dist in enumerate(distances_grid):
# --> 408     kernel_dict[i] = matern_kernel(dist, nu_i, alpha_i, sigma_i)
#     410 # Step 3: Normalize distances and map them to precomputed values using rounding (no gradients needed here)
#     411 # Normalize the pairwise distances to fall between 0 and number_of_distances-1
#     412 normalized_distances = ((pairwise_distances_condensed - min_dist) / (max_dist - min_dist)).detach()
#
# File ~/.conda/envs/pytorch_env/lib/python3.12/site-packages/torch/fx/traceback.py:68, in format_stack()
#      65     return [current_meta.get("stack_trace", "")]
#      66 else:
#      67     # fallback to traceback.format_stack()
# ---> 68     return traceback.format_list(traceback.extract_stack()[:-1])
#
# File ~/.conda/envs/pytorch_env/lib/python3.12/traceback.py:41, in format_list(extracted_list)
#      29 def format_list(extracted_list):
#      30     """Format a list of tuples or FrameSummary objects for printing.
#      31
#      32     Given a list of tuples or FrameSummary objects as returned by
#    (...)
#      39     whose source text line is not None.
#      40     """
# ---> 41     return StackSummary.from_list(extracted_list).format()
#
# File ~/.conda/envs/pytorch_env/lib/python3.12/traceback.py:543, in StackSummary.format(self)
#     541 count = 0
#     542 for frame_summary in self:
# --> 543     formatted_frame = self.format_frame_summary(frame_summary)
#     544     if formatted_frame is None:
#     545         continue
#
# File ~/.conda/envs/pytorch_env/lib/python3.12/traceback.py:467, in StackSummary.format_frame_summary(self, frame_summary)
#     461 """Format the lines for a single FrameSummary.
#     462
#     463 Returns a string representing one frame involved in the stack. This
#     464 gets called for every frame to be printed in the stack summary.
#     465 """
#     466 row = []
# --> 467 row.append('  File "{}", line {}, in {}\n'.format(
#     468     frame_summary.filename, frame_summary.lineno, frame_summary.name))
#     469 if frame_summary.line:
#     470     stripped_line = frame_summary.line.strip()
#
# KeyboardInterrupt:

# %%
optimize_marginal_parameters(X, Y, number_of_groups=1, number_of_cycles=200, steps_per_batch=1)
# Out:
# Final parameters -> alpha_i: 0.00013462897310243817, nu_i: 0.943446150831428, sigma_i: 0.8980020605512565
# Best parameters found -> alpha_i: 0.00013462897310243817, nu_i: 0.943446150831428, sigma_i: 0.8980020605512565
# Final parameters -> alpha_i: 2.220446049250313e-16, nu_i: 0.909515683048815, sigma_i: 1.0368697001864053
# Best parameters found -> alpha_i: 2.220446049250313e-16, nu_i: 0.9095156830488184, sigma_i: 1.036869692129642
# Final parameters -> alpha_i: 2.220446049250313e-16, nu_i: 0.909205322257261, sigma_i: 0.9982888981029192
# Best parameters found -> alpha_i: 2.220446049250313e-16, nu_i: 0.9092053222572632, sigma_i: 0.9982889072994822
# Final parameters -> alpha_i: 0.0026282656667522956, nu_i: 0.8717396826827932, sigma_i: 0.9008355498034345
# Best parameters found -> alpha_i: 0.0026282656667522956, nu_i: 0.8717396826827932, sigma_i: 0.9008355498034345
# Final parameters -> alpha_i: 0.0016138625721242338, nu_i: 0.8207429138991813, sigma_i: 1.0405806655574603
# Best parameters found -> alpha_i: 0.0016138625721242338, nu_i: 0.8207429138991813, sigma_i: 1.0405806655574603
# Final parameters -> alpha_i: 0.0016346959053636064, nu_i: 0.8197924426939999, sigma_i: 1.0012516480645757
# Best parameters found -> alpha_i: 0.0016346959053636064, nu_i: 0.8197924426939999, sigma_i: 1.0012516480645757
# Final parameters -> alpha_i: 0.04274663085386818, nu_i: 0.8471956962439181, sigma_i: 0.961104473887481
# Best parameters found -> alpha_i: 0.04274663085386818, nu_i: 0.8471956962439181, sigma_i: 0.961104473887481
# Final parameters -> alpha_i: 0.04215403062037804, nu_i: 0.8026804123284134, sigma_i: 1.1127576388666103
# Best parameters found -> alpha_i: 0.04215403062037804, nu_i: 0.8026804123284134, sigma_i: 1.1127576388666103
# Final parameters -> alpha_i: 0.042336892883973375, nu_i: 0.7995203060051514, sigma_i: 1.0588005437703911
# Best parameters found -> alpha_i: 0.042336892883973375, nu_i: 0.7995203060051514, sigma_i: 1.0588005437703911
# Final parameters -> alpha_i: 0.1019949675768667, nu_i: 0.9660358202941594, sigma_i: 1.0712742237785533
# Best parameters found -> alpha_i: 0.10109541075005296, nu_i: 0.985874676742808, sigma_i: 1.0668892243050137
# Final parameters -> alpha_i: 0.09201796777881877, nu_i: 0.8216652394462578, sigma_i: 1.201719240228353
# Best parameters found -> alpha_i: 0.09201796777881877, nu_i: 0.8216652394462578, sigma_i: 1.201719240228353
# Final parameters -> alpha_i: 0.09223542105549225, nu_i: 0.8108837626667624, sigma_i: 1.1312959309130755
# Best parameters found -> alpha_i: 0.09223542105549225, nu_i: 0.8108837626667624, sigma_i: 1.1312959309130755
# Final parameters -> alpha_i: 0.20154608566769797, nu_i: 0.9755691187881357, sigma_i: 1.2724899210117542
# Best parameters found -> alpha_i: 0.20068296118678983, nu_i: 0.9875347667694033, sigma_i: 1.270634922321071
# Final parameters -> alpha_i: 0.2018903984153314, nu_i: 0.9671686500317216, sigma_i: 1.4498887284291349
# Best parameters found -> alpha_i: 0.20140475273134384, nu_i: 0.9741630849869849, sigma_i: 1.4467940064077685
# Final parameters -> alpha_i: 0.2049263359835036, nu_i: 0.8480908133938047, sigma_i: 1.3194385925138816
# Best parameters found -> alpha_i: 0.2049263359835036, nu_i: 0.8480908133938047, sigma_i: 1.3194385925138816
# Final parameters -> alpha_i: 0.00013462897310243817, nu_i: 0.943446150831428, sigma_i: 0.8980020605512565
# Best parameters found -> alpha_i: 0.00013462897310243817, nu_i: 0.943446150831428, sigma_i: 0.8980020605512565
# Final parameters -> alpha_i: 2.220446049250313e-16, nu_i: 0.909515683048815, sigma_i: 1.0368697001864053
# Best parameters found -> alpha_i: 2.220446049250313e-16, nu_i: 0.9095156830488184, sigma_i: 1.036869692129642
# Final parameters -> alpha_i: 2.220446049250313e-16, nu_i: 0.909205322257261, sigma_i: 0.9982888981029192
# Best parameters found -> alpha_i: 2.220446049250313e-16, nu_i: 0.9092053222572632, sigma_i: 0.9982889072994822
# Final parameters -> alpha_i: 0.0026282656667522956, nu_i: 0.8717396826827932, sigma_i: 0.9008355498034345
# Best parameters found -> alpha_i: 0.0026282656667522956, nu_i: 0.8717396826827932, sigma_i: 0.9008355498034345
# Final parameters -> alpha_i: 0.0016138625721242338, nu_i: 0.8207429138991813, sigma_i: 1.0405806655574603
# Best parameters found -> alpha_i: 0.0016138625721242338, nu_i: 0.8207429138991813, sigma_i: 1.0405806655574603
# Final parameters -> alpha_i: 0.0016346959053636064, nu_i: 0.8197924426939999, sigma_i: 1.0012516480645757
# Best parameters found -> alpha_i: 0.0016346959053636064, nu_i: 0.8197924426939999, sigma_i: 1.0012516480645757
# Final parameters -> alpha_i: 0.04274663085386818, nu_i: 0.8471956962439181, sigma_i: 0.961104473887481
# Best parameters found -> alpha_i: 0.04274663085386818, nu_i: 0.8471956962439181, sigma_i: 0.961104473887481
# Final parameters -> alpha_i: 0.04215403062037804, nu_i: 0.8026804123284134, sigma_i: 1.1127576388666103
# Best parameters found -> alpha_i: 0.04215403062037804, nu_i: 0.8026804123284134, sigma_i: 1.1127576388666103
# Final parameters -> alpha_i: 0.042336892883973375, nu_i: 0.7995203060051514, sigma_i: 1.0588005437703911
# Best parameters found -> alpha_i: 0.042336892883973375, nu_i: 0.7995203060051514, sigma_i: 1.0588005437703911
# Final parameters -> alpha_i: 0.1019949675768667, nu_i: 0.9660358202941594, sigma_i: 1.0712742237785533
# Best parameters found -> alpha_i: 0.10109541075005296, nu_i: 0.985874676742808, sigma_i: 1.0668892243050137
# Final parameters -> alpha_i: 0.09201796777881877, nu_i: 0.8216652394462578, sigma_i: 1.201719240228353
# Best parameters found -> alpha_i: 0.09201796777881877, nu_i: 0.8216652394462578, sigma_i: 1.201719240228353
# Final parameters -> alpha_i: 0.09223542105549225, nu_i: 0.8108837626667624, sigma_i: 1.1312959309130755
# Best parameters found -> alpha_i: 0.09223542105549225, nu_i: 0.8108837626667624, sigma_i: 1.1312959309130755
# Final parameters -> alpha_i: 0.20154608566769797, nu_i: 0.9755691187881357, sigma_i: 1.2724899210117542
# Best parameters found -> alpha_i: 0.20068296118678983, nu_i: 0.9875347667694033, sigma_i: 1.270634922321071
# Final parameters -> alpha_i: 0.2018903984153314, nu_i: 0.9671686500317216, sigma_i: 1.4498887284291349
# Best parameters found -> alpha_i: 0.20140475273134384, nu_i: 0.9741630849869849, sigma_i: 1.4467940064077685
# Final parameters -> alpha_i: 0.2049263359835036, nu_i: 0.8480908133938047, sigma_i: 1.3194385925138816
# Best parameters found -> alpha_i: 0.2049263359835036, nu_i: 0.8480908133938047, sigma_i: 1.3194385925138816
# Final parameters -> alpha_i: 0.00013462897310243817, nu_i: 0.943446150831428, sigma_i: 0.8980020605512565
# Best parameters found -> alpha_i: 0.00013462897310243817, nu_i: 0.943446150831428, sigma_i: 0.8980020605512565
# Final parameters -> alpha_i: 2.220446049250313e-16, nu_i: 0.909515683048815, sigma_i: 1.0368697001864053
# Best parameters found -> alpha_i: 2.220446049250313e-16, nu_i: 0.9095156830488184, sigma_i: 1.036869692129642
# Final parameters -> alpha_i: 2.220446049250313e-16, nu_i: 0.909205322257261, sigma_i: 0.9982888981029192
# Best parameters found -> alpha_i: 2.220446049250313e-16, nu_i: 0.9092053222572632, sigma_i: 0.9982889072994822
# Final parameters -> alpha_i: 0.0026282656667522956, nu_i: 0.8717396826827932, sigma_i: 0.9008355498034345
# Best parameters found -> alpha_i: 0.0026282656667522956, nu_i: 0.8717396826827932, sigma_i: 0.9008355498034345
# Final parameters -> alpha_i: 0.0016138625721242338, nu_i: 0.8207429138991813, sigma_i: 1.0405806655574603
# Best parameters found -> alpha_i: 0.0016138625721242338, nu_i: 0.8207429138991813, sigma_i: 1.0405806655574603
# Final parameters -> alpha_i: 0.0016346959053636064, nu_i: 0.8197924426939999, sigma_i: 1.0012516480645757
# Best parameters found -> alpha_i: 0.0016346959053636064, nu_i: 0.8197924426939999, sigma_i: 1.0012516480645757
# Final parameters -> alpha_i: 0.04274663085386818, nu_i: 0.8471956962439181, sigma_i: 0.961104473887481
# Best parameters found -> alpha_i: 0.04274663085386818, nu_i: 0.8471956962439181, sigma_i: 0.961104473887481
# Final parameters -> alpha_i: 0.04215403062037804, nu_i: 0.8026804123284134, sigma_i: 1.1127576388666103
# Best parameters found -> alpha_i: 0.04215403062037804, nu_i: 0.8026804123284134, sigma_i: 1.1127576388666103
# Final parameters -> alpha_i: 0.042336892883973375, nu_i: 0.7995203060051514, sigma_i: 1.0588005437703911
# Best parameters found -> alpha_i: 0.042336892883973375, nu_i: 0.7995203060051514, sigma_i: 1.0588005437703911
# Final parameters -> alpha_i: 0.1019949675768667, nu_i: 0.9660358202941594, sigma_i: 1.0712742237785533
# Best parameters found -> alpha_i: 0.10109541075005296, nu_i: 0.985874676742808, sigma_i: 1.0668892243050137

# %%
ground_truth_df
# Out:
#    alpha_matrix_11  nu_matrix_11  sigma_matrix_11  alpha_matrix_12  \
# 0             0.01           1.2              1.0           0.0205
#
#    nu_matrix_12  sigma_matrix_12  alpha_matrix_13  nu_matrix_13  \
# 0         1.093           -0.286           0.0263         1.092
#
#    sigma_matrix_13  alpha_matrix_22  nu_matrix_22  sigma_matrix_22  \
# 0           -0.181             0.02           0.6              1.0
#
#    alpha_matrix_23  nu_matrix_23  sigma_matrix_23  alpha_matrix_33  \
# 0           0.0282          0.99            0.274             0.03
#
#    nu_matrix_33  sigma_matrix_33
# 0           0.3              1.0
