# %%
from IPython.display import Javascript, display
import json

def get_notebook_name():
    js_code = """
    IPython.notebook.kernel.execute('notebook_name = "' + IPython.notebook.notebook_name + '"')
    """
    display(Javascript(js_code))

get_notebook_name()

# %%
# !pip install ipynbname
# Out:
# Collecting ipynbname
#   Downloading ipynbname-2024.1.0.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: ipykernel in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipynbname) (6.29.3)
# Requirement already satisfied: comm>=0.1.1 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (8.22.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (1.6.0)
# Requirement already satisfied: packaging in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (23.2)
# Requirement already satisfied: psutil in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipykernel->ipynbname) (5.14.1)
# Requirement already satisfied: decorator in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (2.17.2)
# Requirement already satisfied: stack-data in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->ipynbname) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel->ipynbname) (2.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->ipynbname) (4.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->ipynbname) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->ipynbname) (0.7.0)
# Requirement already satisfied: wcwidth in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->ipynbname) (0.2.13)
# Requirement already satisfied: six>=1.5 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->ipynbname) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->ipynbname) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->ipynbname) (2.4.1)
# Requirement already satisfied: pure-eval in /home/zc362/.conda/envs/pytorch_env/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->ipynbname) (0.2.2)
# Downloading ipynbname-2024.1.0.0-py3-none-any.whl (4.3 kB)
# Installing collected packages: ipynbname
# Successfully installed ipynbname-2024.1.0.0
