# %%
import os
import numpy as np
import pandas as pd

def calculate_frobenius_norm(i, j):
    """
    Reads a CSV file and calculates its Frobenius norm.
    
    Parameters:
        i (int): First identifier in the file path.
        j (int): Second identifier in the file path.
        
    Returns:
        float: Frobenius norm of the matrix.
    """
    # Construct the file path
    file_path = os.path.expanduser(f"~/project/41_3_test_cov/K_test_{i}_{j}.csv")
    
    try:
        # Read the CSV file
        matrix = pd.read_csv(file_path).values
        # Calculate the Frobenius norm
        frobenius_norm = np.linalg.norm(matrix, 'fro')
        print(f"Frobenius norm for K_test_{i}_{j}.csv: {frobenius_norm}")
        return frobenius_norm
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

# Example usage
# Replace i and j with specific values
for i in range(2):
    for j in range(3):
        calculate_frobenius_norm(i, j)
# Out:
# Frobenius norm for K_test_0_0.csv: 31.750359826660493
# Frobenius norm for K_test_0_1.csv: 31.67338707526074
# Frobenius norm for K_test_0_2.csv: 31.625971578118904
# Frobenius norm for K_test_1_0.csv: 47.94158384093358
# Frobenius norm for K_test_1_1.csv: 32.04237754907616
# Frobenius norm for K_test_1_2.csv: 31.61015641896092
